# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('scene.png', 0)

equ = cv2.equalizeHist(img)
res = np.hstack((img,equ))

cv2.imwrite('scene_equ.jpg', equ)
# Out:
# True

# %%
img = cv2.imread('Book4.png', 1)
print(img.shape)

img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)

# equalize the histogram of the Y channel
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])

# convert the YUV image back to RGB format
img_output = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)

cv2.imwrite('img_result1_4.jpg', img_output)
# Out:
# (370, 463, 3)
# True

# %%
img = cv2.imread('Book4.png')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
img = cv2.imread('Book1.png',0)

hist,bins = np.histogram(img.flatten(),256,[0,256])

plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.show()
# Out:
# /tmp/ipykernel_14513/871514252.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img.flatten(),256,[0,256], color = 'r')

# %%
plt.hist(img.flatten(),256,[0,256], color = 'r', density=True)
plt.xlim([0,256])
plt.show()
# Out:
# /tmp/ipykernel_14513/2184628015.py:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img.flatten(),256,[0,256], color = 'r', density=True)

# %%
cdf = hist.cumsum()
cdf_normalized = cdf/cdf.max()

plt.plot(cdf_normalized, color = 'g')
plt.xlim([-1,256])
plt.show()

# %%
#cdf = hist.cumsum()
#cdf_normalized = cdf/cdf.max()

plt.plot(cdf_normalized, color = 'g')
plt.hist(img.flatten(),256,[0,256], color = 'r', density=True)
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.xlim([-1,256])
plt.show()
# Out:
# /tmp/ipykernel_14513/1488755590.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img.flatten(),256,[0,256], color = 'r', density=True)
