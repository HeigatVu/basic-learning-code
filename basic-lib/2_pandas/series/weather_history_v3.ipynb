# %%
import numpy as np
import pandas as pd

df = pd.read_csv('weatherHistory_v3.csv')

data_series = pd.Series(data=df.iloc[:,0])
data_series.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 49327 entries, 0 to 49326
# Series name: Temperature (C)
# Non-Null Count  Dtype
# --------------  -----
# 49327 non-null  float64
# dtypes: float64(1)
# memory usage: 385.5 KB

# %%
print(data_series.size)
print(data_series.dtypes)
print(data_series.shape)
# Out:
# 49327
# float64
# (49327,)

# %%
data_series.describe()
# Out:
# count    49327.000000
# mean         8.792028
# std          7.712077
# min        -21.822222
# 25%          2.766667
# 50%          9.005556
# 75%         15.122222
# max         21.994444
# Name: Temperature (C), dtype: float64

# %%
data_series.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
data_series.hist()
# Out:
# <Axes: >

# %%
data_series.plot.box()
# Out:
# <Axes: >
